# %%
# Importing essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Importing dataset
data = pd.read_csv('/Users/yasmin/Downloads/advertsuccess/Train.csv')
data
# Out:
#           id    realtionship_status       industry        genre targeted_sex  \
# 0      19717  Married-spouse-absent           Auto       Comedy         Male
# 1      31593     Married-civ-spouse         Pharma       Comedy         Male
# 2       5681               Divorced  Entertainment       Comedy       Female
# 3      15491              Separated      Political  Infomercial       Female
# 4      23587     Married-civ-spouse         Pharma       Comedy         Male
# ...      ...                    ...            ...          ...          ...
# 26043  16009     Married-civ-spouse         Pharma       Comedy         Male
# 26044  17241          Never-married           Auto       Comedy       Female
# 26045   2295     Married-civ-spouse          Other       Comedy       Female
# 26046  17902          Never-married           Auto       Comedy       Female
# 26047  30877     Married-civ-spouse         Pharma  Infomercial         Male
#
# ...

# %%
data.describe()
# Out:
#                  id  average_runtime(minutes_per_week)       ratings
# count  26048.000000                       26048.000000  26048.000000
# mean   16268.744779                          40.294111      0.038716
# std     9413.578020                          12.479457      0.075852
# min        2.000000                           1.000000      0.000000
# 25%     8095.750000                          40.000000      0.027465
# 50%    16237.000000                          40.000000      0.027465
# 75%    24413.500000                          45.000000      0.027465
# max    32561.000000                          99.000000      1.000000

# %%
data.realtionship_status.value_counts()
# Out:
# Married-civ-spouse       11844
# Never-married             8547
# Divorced                  3649
# Widowed                    818
# Separated                  793
# Married-spouse-absent      378
# Married-AF-spouse           19
# Name: realtionship_status, dtype: int64

# %%
del data['id']
data
# Out:
#          realtionship_status       industry        genre targeted_sex  \
# 0      Married-spouse-absent           Auto       Comedy         Male
# 1         Married-civ-spouse         Pharma       Comedy         Male
# 2                   Divorced  Entertainment       Comedy       Female
# 3                  Separated      Political  Infomercial       Female
# 4         Married-civ-spouse         Pharma       Comedy         Male
# ...                      ...            ...          ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy         Male
# 26044          Never-married           Auto       Comedy       Female
# 26045     Married-civ-spouse          Other       Comedy       Female
# 26046          Never-married           Auto       Comedy       Female
# 26047     Married-civ-spouse         Pharma  Infomercial         Male
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# ...

# %%
data['targeted_sex'] = data['targeted_sex'].astype('category')
data.dtypes
# Out:
# realtionship_status                    object
# industry                               object
# genre                                  object
# targeted_sex                         category
# average_runtime(minutes_per_week)       int64
# airtime                                object
# airlocation                            object
# ratings                               float64
# expensive                              object
# money_back_guarantee                   object
# netgain                                  bool
# dtype: object

# %%
data['targeted_sex_cat'] = data['targeted_sex'].cat.codes
data
# Out:
#          realtionship_status       industry        genre targeted_sex  \
# 0      Married-spouse-absent           Auto       Comedy         Male
# 1         Married-civ-spouse         Pharma       Comedy         Male
# 2                   Divorced  Entertainment       Comedy       Female
# 3                  Separated      Political  Infomercial       Female
# 4         Married-civ-spouse         Pharma       Comedy         Male
# ...                      ...            ...          ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy         Male
# 26044          Never-married           Auto       Comedy       Female
# 26045     Married-civ-spouse          Other       Comedy       Female
# 26046          Never-married           Auto       Comedy       Female
# 26047     Married-civ-spouse         Pharma  Infomercial         Male
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# ...

# %%
data.targeted_sex_cat.value_counts()
# Out:
# 1    17245
# 0     8803
# Name: targeted_sex_cat, dtype: int64

# %%
data.targeted_sex.value_counts()
# Out:
# Male      17245
# Female     8803
# Name: targeted_sex, dtype: int64

# %%
del data['targeted_sex']
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# 0                                     45  Primetime  United-States  0.027465
# 1                                     45  Primetime  United-States  0.027465
# ...

# %%
data['netgain'] = data['netgain'].astype('category')
data.dtypes
# Out:
# realtionship_status                    object
# industry                               object
# genre                                  object
# average_runtime(minutes_per_week)       int64
# airtime                                object
# airlocation                            object
# ratings                               float64
# expensive                              object
# money_back_guarantee                   object
# netgain                              category
# targeted_sex_cat                         int8
# dtype: object

# %%
data['netgain_cat'] = data['netgain'].cat.codes
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# 0                                     45  Primetime  United-States  0.027465
# 1                                     45  Primetime  United-States  0.027465
# ...

# %%
del data['netgain']
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# 0                                     45  Primetime  United-States  0.027465
# 1                                     45  Primetime  United-States  0.027465
# ...

# %%
data.industry.value_counts()
# Out:
# Pharma           10339
# Auto              6801
# Political         4014
# Entertainment     2765
# Other             1333
# ClassAction        796
# Name: industry, dtype: int64

# %%
data['money_back_guarantee'] = data['money_back_guarantee'].astype('category')
data.dtypes
# Out:
# realtionship_status                    object
# industry                               object
# genre                                  object
# average_runtime(minutes_per_week)       int64
# airtime                                object
# airlocation                            object
# ratings                               float64
# expensive                              object
# money_back_guarantee                 category
# targeted_sex_cat                         int8
# netgain_cat                              int8
# dtype: object

# %%
data['money_back_guarantee_cat'] = data['money_back_guarantee'].cat.codes
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# 0                                     45  Primetime  United-States  0.027465
# 1                                     45  Primetime  United-States  0.027465
# ...

# %%
del data['money_back_guarantee']
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# 0                                     45  Primetime  United-States  0.027465
# 1                                     45  Primetime  United-States  0.027465
# ...

# %%
data.expensive.value_counts()
# Out:
# Low       15693
# High       7279
# Medium     3076
# Name: expensive, dtype: int64

# %%
data = pd.concat([data,pd.get_dummies(data['expensive'],prefix='expensive')],axis=1)
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# 0                                     45  Primetime  United-States  0.027465
# 1                                     45  Primetime  United-States  0.027465
# ...

# %%
del data['expensive']
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime    airlocation   ratings  \
# 0                                     45  Primetime  United-States  0.027465
# 1                                     45  Primetime  United-States  0.027465
# ...

# %%
data.airlocation.value_counts()
# Out:
# United-States                 23250
# Mexico                          523
# International                   465
# Philippines                     141
# Germany                         114
# Canada                           94
# Cuba                             86
# Puerto-Rico                      85
# El-Salvador                      84
# India                            81
# England                          79
# Italy                            70
# South                            69
# Poland                           66
# Jamaica                          63
# Dominican-Republic               62
# Guatemala                        61
# Vietnam                          57
# Columbia                         55
# Japan                            54
# China                            53
# Taiwan                           37
# Iran                             36
# Haiti                            35
# Ecuador                          31
# Portugal                         30
# ...

# %%
# Import label encoder 
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
data['airlocation']= label_encoder.fit_transform(data['airlocation']) 
  
data['airlocation'].unique()
# Out:
# array([39, 28, 26, 25, 19, 18, 31, 35, 22, 30, 12,  3, 36,  8,  1, 10, 37,
#        33, 27,  4, 38, 41,  7, 29,  2, 24, 40, 16,  5, 15, 17, 23,  9, 32,
#        21,  6, 20, 34, 11,  0, 13, 14])

# %%
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime  airlocation   ratings  \
# 0                                     45  Primetime           39  0.027465
# 1                                     45  Primetime           39  0.027465
# ...

# %%
data.airlocation.value_counts()
# Out:
# 39    23250
# 26      523
# 19      465
# 30      141
# 10      114
# 1        94
# 4        86
# 33       85
# 7        84
# 18       81
# 8        79
# 22       70
# 35       69
# 31       66
# 23       63
# 5        62
# 12       61
# 40       57
# 3        55
# 24       54
# 2        53
# 36       37
# 20       36
# 13       35
# 6        31
# 32       30
# 29       28
# 27       28
# 9        27
# 41       24
# 21       22
# 38       17
# 25       17
# 11       16
# 0        16
# 15       15
# 16       14
# 37       13
# 34       12
# 17        8
# 28        8
# 14        2
# Name: airlocation, dtype: int64

# %%
data.airtime.value_counts()
# Out:
# Primetime    15652
# Morning       8531
# Daytime       1865
# Name: airtime, dtype: int64

# %%
data = pd.concat([data,pd.get_dummies(data['airtime'],prefix='airtime')],axis=1)
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)    airtime  airlocation   ratings  \
# 0                                     45  Primetime           39  0.027465
# 1                                     45  Primetime           39  0.027465
# ...

# %%
del data['airtime']
data
# Out:
#          realtionship_status       industry        genre  \
# 0      Married-spouse-absent           Auto       Comedy
# 1         Married-civ-spouse         Pharma       Comedy
# 2                   Divorced  Entertainment       Comedy
# 3                  Separated      Political  Infomercial
# 4         Married-civ-spouse         Pharma       Comedy
# ...                      ...            ...          ...
# 26043     Married-civ-spouse         Pharma       Comedy
# 26044          Never-married           Auto       Comedy
# 26045     Married-civ-spouse          Other       Comedy
# 26046          Never-married           Auto       Comedy
# 26047     Married-civ-spouse         Pharma  Infomercial
#
#        average_runtime(minutes_per_week)  airlocation   ratings  \
# 0                                     45           39  0.027465
# 1                                     45           39  0.027465
# 2                                     45           39  0.027465
# ...

# %%
data.genre.value_counts()
# Out:
# Comedy         22258
# Infomercial     2516
# Drama            803
# Direct           247
# Other            224
# Name: genre, dtype: int64

# %%
data = pd.concat([data,pd.get_dummies(data['genre'],prefix='genre')],axis=1)
del data['genre']
data
# Out:
#          realtionship_status       industry  \
# 0      Married-spouse-absent           Auto
# 1         Married-civ-spouse         Pharma
# 2                   Divorced  Entertainment
# 3                  Separated      Political
# 4         Married-civ-spouse         Pharma
# ...                      ...            ...
# 26043     Married-civ-spouse         Pharma
# 26044          Never-married           Auto
# 26045     Married-civ-spouse          Other
# 26046          Never-married           Auto
# 26047     Married-civ-spouse         Pharma
#
#        average_runtime(minutes_per_week)  airlocation   ratings  \
# 0                                     45           39  0.027465
# 1                                     45           39  0.027465
# 2                                     45           39  0.027465
# 3                                     40           39  0.027465
# 4                                     48           39  0.027465
# ...

# %%
data.industry.value_counts()
# Out:
# Pharma           10339
# Auto              6801
# Political         4014
# Entertainment     2765
# Other             1333
# ClassAction        796
# Name: industry, dtype: int64

# %%
data = pd.concat([data,pd.get_dummies(data['industry'],prefix='industry')],axis=1)
del data['industry']
data
# Out:
#          realtionship_status  average_runtime(minutes_per_week)  airlocation  \
# 0      Married-spouse-absent                                 45           39
# 1         Married-civ-spouse                                 45           39
# 2                   Divorced                                 45           39
# 3                  Separated                                 40           39
# 4         Married-civ-spouse                                 48           39
# ...                      ...                                ...          ...
# 26043     Married-civ-spouse                                 50           39
# 26044          Never-married                                 40           39
# 26045     Married-civ-spouse                                 25           39
# 26046          Never-married                                 48           39
# 26047     Married-civ-spouse                                 40           39
#
# ...

# %%
data.realtionship_status.value_counts()
# Out:
# Married-civ-spouse       11844
# Never-married             8547
# Divorced                  3649
# Widowed                    818
# Separated                  793
# Married-spouse-absent      378
# Married-AF-spouse           19
# Name: realtionship_status, dtype: int64

# %%
data = pd.concat([data,pd.get_dummies(data['realtionship_status'],prefix='realtionship_status')],axis=1)
del data['realtionship_status']
data
# Out:
#        average_runtime(minutes_per_week)  airlocation   ratings  \
# 0                                     45           39  0.027465
# 1                                     45           39  0.027465
# 2                                     45           39  0.027465
# 3                                     40           39  0.027465
# 4                                     48           39  0.027465
# ...                                  ...          ...       ...
# 26043                                 50           39  0.027465
# 26044                                 40           39  0.027465
# 26045                                 25           39  0.102234
# 26046                                 48           39  0.027465
# 26047                                 40           39  0.027465
#
#        targeted_sex_cat  netgain_cat  money_back_guarantee_cat  \
# 0                     1            0                         0
# 1                     1            0                         0
# ...

# %%
data['average_runtime(minutes_per_week)'].value_counts()
# Out:
# 40    12070
# 50     2216
# 45     1485
# 60     1119
# 20     1064
#       ...
# 74        1
# 76        1
# 92        1
# 61        1
# 87        1
# Name: average_runtime(minutes_per_week), Length: 91, dtype: int64

# %%
data['average_runtime(minutes_per_week)'].min()
# Out:
# 1

# %%
data['average_runtime(minutes_per_week)'].max()
# Out:
# 99

# %%
customcut = np.linspace(0, 99, 10)
customcut
# Out:
# array([ 0., 11., 22., 33., 44., 55., 66., 77., 88., 99.])

# %%
data['average_runtime(minutes_per_week)'] = pd.cut(data['average_runtime(minutes_per_week)'], customcut)

# %%
data
# Out:
#       average_runtime(minutes_per_week)  airlocation   ratings  \
# 0                          (44.0, 55.0]           39  0.027465
# 1                          (44.0, 55.0]           39  0.027465
# 2                          (44.0, 55.0]           39  0.027465
# 3                          (33.0, 44.0]           39  0.027465
# 4                          (44.0, 55.0]           39  0.027465
# ...                                 ...          ...       ...
# 26043                      (44.0, 55.0]           39  0.027465
# 26044                      (33.0, 44.0]           39  0.027465
# 26045                      (22.0, 33.0]           39  0.102234
# 26046                      (44.0, 55.0]           39  0.027465
# 26047                      (33.0, 44.0]           39  0.027465
#
#        targeted_sex_cat  netgain_cat  money_back_guarantee_cat  \
# 0                     1            0                         0
# 1                     1            0                         0
# ...

# %%
data['average_runtime(minutes_per_week)'] = data['average_runtime(minutes_per_week)'].astype('category')
data.dtypes
# Out:
# average_runtime(minutes_per_week)            category
# airlocation                                     int64
# ratings                                       float64
# targeted_sex_cat                                 int8
# netgain_cat                                      int8
# money_back_guarantee_cat                         int8
# expensive_High                                  uint8
# expensive_Low                                   uint8
# expensive_Medium                                uint8
# airtime_Daytime                                 uint8
# airtime_Morning                                 uint8
# airtime_Primetime                               uint8
# genre_Comedy                                    uint8
# genre_Direct                                    uint8
# genre_Drama                                     uint8
# genre_Infomercial                               uint8
# genre_Other                                     uint8
# ...

# %%
data['average_runtime_cat'] = data['average_runtime(minutes_per_week)'].cat.codes
data
# Out:
#       average_runtime(minutes_per_week)  airlocation   ratings  \
# 0                          (44.0, 55.0]           39  0.027465
# 1                          (44.0, 55.0]           39  0.027465
# 2                          (44.0, 55.0]           39  0.027465
# 3                          (33.0, 44.0]           39  0.027465
# 4                          (44.0, 55.0]           39  0.027465
# ...                                 ...          ...       ...
# 26043                      (44.0, 55.0]           39  0.027465
# 26044                      (33.0, 44.0]           39  0.027465
# 26045                      (22.0, 33.0]           39  0.102234
# 26046                      (44.0, 55.0]           39  0.027465
# 26047                      (33.0, 44.0]           39  0.027465
#
#        targeted_sex_cat  netgain_cat  money_back_guarantee_cat  \
# 0                     1            0                         0
# 1                     1            0                         0
# ...

# %%
data.average_runtime_cat.value_counts()
# Out:
# 3    14342
# 4     4971
# 2     2102
# 1     1898
# 5     1482
# 0      608
# 6      335
# 7      177
# 8      133
# Name: average_runtime_cat, dtype: int64

# %%
del data['average_runtime(minutes_per_week)']
data
# Out:
#        airlocation   ratings  targeted_sex_cat  netgain_cat  \
# 0               39  0.027465                 1            0
# 1               39  0.027465                 1            0
# 2               39  0.027465                 0            0
# 3               39  0.027465                 0            0
# 4               39  0.027465                 1            1
# ...            ...       ...               ...          ...
# 26043           39  0.027465                 1            1
# 26044           39  0.027465                 0            0
# 26045           39  0.102234                 0            1
# 26046           39  0.027465                 0            0
# 26047           39  0.027465                 1            0
#
#        money_back_guarantee_cat  expensive_High  expensive_Low  \
# 0                             0               1              0
# 1                             0               0              1
# ...

# %%
data.ratings.value_counts()
# Out:
# 0.027465    23736
# 0.173580      303
# 0.102234      227
# 0.098441      201
# 1.000000      143
#             ...
# 0.056019        1
# 0.073048        1
# 0.173541        1
# 0.076675        1
# 0.041615        1
# Name: ratings, Length: 125, dtype: int64

# %%
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
data['ratings']= label_encoder.fit_transform(data['ratings']) 
  
data['ratings'].unique()
# Out:
# array([  9,  57, 115, 105, 101,  58, 104,  98, 118,  50,  18,  92, 124,
#         23,   7,  64,  68,  22,  71,  75, 121, 112,  35,  66,  42,  10,
#         86,  47,  25, 107,   0, 108,  44,  51,  73,  84,  33,  97, 117,
#         60,  69,  26, 109,  81,  61,  24,   8, 120,  34,  65, 113,  62,
#         15,  87,  30,   3, 111,  72,  80,  78,  27,  89,  56,  21,  36,
#         12,  48,  82,  96,  88,  63,  59, 100,  95,   2,   4,  14,  94,
#         32,  93,  20,  74,  52,  43,  19,  76,  13, 122,  40,  55,  16,
#         91, 106,  83, 102,  77,  39,  70,  46,  49,  99, 110,  28,  67,
#         17,  54,  31,  29, 119,  90,   5,  45, 123,  37,  85,   1, 116,
#        103,  38,  79,   6,  11,  41,  53, 114])

# %%
data.ratings.value_counts()
# Out:
# 9      23736
# 115      303
# 101      227
# 98       201
# 124      143
#        ...
# 114        1
# 13         1
# 5          1
# 79         1
# 41         1
# Name: ratings, Length: 125, dtype: int64

# %%
data['netgains_cat'] = data['netgain_cat']
del data['netgain_cat']
data
# Out:
#        airlocation  ratings  targeted_sex_cat  money_back_guarantee_cat  \
# 0               39        9                 1                         0
# 1               39        9                 1                         0
# 2               39        9                 0                         1
# 3               39        9                 0                         0
# 4               39        9                 1                         0
# ...            ...      ...               ...                       ...
# 26043           39        9                 1                         0
# 26044           39        9                 0                         0
# 26045           39      101                 0                         0
# 26046           39        9                 0                         1
# 26047           39        9                 1                         1
#
#        expensive_High  expensive_Low  expensive_Medium  airtime_Daytime  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
X = data.values[:, 0:29]
y = data.values[:, 29:30]
y
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]])

# %%
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB

# %%
seed = 7
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size= 0.2, random_state= seed)
y_train= y_train.ravel()
y_train
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from warnings import simplefilter
simplefilter(action='ignore')
models = []
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
# Calculating each model's prediction
results = []
names = []
for name, model in models:
    Results = model_selection.cross_val_score(model, X_train, y_train, scoring= 'accuracy')
    results.append(Results)
    names.append(name)

# %%
# Algorithm Comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
myList = list(range(0,50))
neighbors = list(filter(lambda x: x%2!=0, myList))  #This will give a list of odd numbers only ranging from 0 to 50

CV_Scores = []

for k in neighbors:
    KNN = KNeighborsClassifier(n_neighbors = k)
    KNN.fit(X_train, y_train)
    scores = KNN.score(X_test, y_test)
    CV_Scores.append(scores)

# %%
CV_Scores
# Out:
# [0.7414587332053743,
#  0.7932821497120921,
#  0.800383877159309,
#  0.8047984644913627,
#  0.8055662188099808,
#  0.8046065259117082,
#  0.8055662188099808,
#  0.80978886756238,
#  0.8092130518234165,
#  0.8099808061420346,
#  0.8109404990403071,
#  0.8163147792706335,
#  0.8143953934740883,
#  0.807869481765835,
#  0.8057581573896353,
#  0.8076775431861805,
#  0.8071017274472169,
#  0.8076775431861805,
#  0.80978886756238,
#  0.8168905950095969,
#  0.8170825335892514,
#  0.8174664107485604,
#  0.817658349328215,
#  0.818809980806142,
#  0.8159309021113244]

# %%
plt.figure(figsize = (14, 12))
plt.plot(neighbors, CV_Scores)
plt.title("Neighbors Vs Score", fontsize=25)
plt.xlabel("Number of Neighbors", fontsize=25)
plt.ylabel("Score", fontsize=25)
plt.grid(linestyle='-', linewidth=0.5)

# %%
bestknn = max(CV_Scores)

# %%
bestknn
# Out:
# 0.818809980806142

# %%
loglinear = LinearDiscriminantAnalysis()
loglinear.fit(X_train, y_train)
y_pred = loglinear.predict(X_test)
print('Accuracy of LinearDiscriminantAnalysis on test set: {:.2f}'.format(loglinear.score(X_test, y_test)))
# Out:
# Accuracy of LinearDiscriminantAnalysis on test set: 0.80

# %%
logtree = DecisionTreeClassifier()
logtree.fit(X_train, y_train)
y_pred = logtree.predict(X_test)
print('Accuracy of DecisionTreeClassifier on test set: {:.2f}'.format(logtree.score(X_test, y_test)))
# Out:
# Accuracy of DecisionTreeClassifier on test set: 0.81

# %%
logknn = KNeighborsClassifier()
logknn.fit(X_train, y_train)
y_pred = logknn.predict(X_test)
print('Accuracy of KNeighborsClassifier on test set: {:.2f}'.format(logknn.score(X_test, y_test)))
# Out:
# Accuracy of KNeighborsClassifier on test set: 0.80
